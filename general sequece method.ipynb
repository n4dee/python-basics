# %%
strsample = 'learning is fun'
print(strsample)
# Out:
# learning is fun

# %%
strsample.capitalize()
# Out:
# 'Learning is fun'

# %%
strsample.title()
# Out:
# 'Learning Is Fun'

# %%
strsample.swapcase()
# Out:
# 'LEARNING IS FUN'

# %%
name1 = 'nadeem'
name2 = 'plays'
name3 = 'football'

# %%
name = '{} {} {}.' .format(name1, name2, name3)
print(name)
# Out:
# nadeem plays football.
