# %%
my_list =[1,2,3,4,5,6]
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import numpy as np

# %%
array = np.array( my_list ,dtype=int)
print(array)
# Out:
# [1 2 3 4 5 6]

# %%
print(len(array))
print(type(array))
print(array.ndim)
print(array.shape)
print(array.dtype)
# Out:
# 6
# <class 'numpy.ndarray'>
# 1
# (6,)
# int64

# %%
array2=(array.reshape(2,3))
print(array2)
array2.shape
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)

# %%
my_list2 = [1,2,3,4,5]
my_list3 = [2,3,4,5,6]
my_list4 = [9,7,6,8,9]
